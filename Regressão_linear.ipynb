# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_regression
from sklearn.linear_model import LinearRegression

# %%
# Gerando os dados com make_regression
x, y = make_regression(n_samples=200, n_features=1, noise=30)

# Evitando valores negativos nos dados
x = np.abs(x)
y = np.abs(y)

# Convertendo os dados para um formato de matriz 2D (x e y lado a lado)
data = np.column_stack((x, y))

# Salvando os dados em um arquivo .txt sem números negativos
file_path = 'dados_txt0.txt'
np.savetxt(file_path, data, delimiter=',', header='x,y', comments='')

# Exibindo o caminho do arquivo salvo
file_path
plt.scatter(x,y)

# %%
modelo = LinearRegression()
modelo.fit(x,y)
# Out:
# LinearRegression()

# %%
a_coeff = modelo.coef_
l_coeff = modelo.intercept_

y = a + b*x
y = l_coeff + a_coeff * x
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[164], line 4
#       1 a_coeff = modelo.coef_
#       2 l_coeff = modelo.intercept_
# ----> 4 y = a + b*x
#       5 y = l_coeff + a_coeff * x
#
# NameError: name 'a' is not defined

# %%
print('Coeficiente Angular: {0}\nCoeficiente Linear {1}'.format(a_coeff,l_coeff))
# Out:
# Coeficiente Angular: [-1.68072938]
# Coeficiente Linear 27.181392845951187

# %%
plt.scatter(x,y)
plt.plot(x, l_coeff + a_coeff*x , color='red')
plt.scatter(2.5, l_coeff + a_coeff*2.5, color='green')
plt.show()
