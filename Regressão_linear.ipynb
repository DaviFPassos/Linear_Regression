# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_regression
from sklearn.linear_model import LinearRegression

# %%
# Gerando os dados com make_regression
x, y = make_regression(n_samples=200, n_features=1, noise=30)

# Evitando valores negativos nos dados
x = np.abs(x)
y = np.abs(y)

# Convertendo os dados para um formato de matriz 2D (x e y lado a lado)
data = np.column_stack((x, y))

# Salvando os dados em um arquivo .txt sem números negativos
file_path = 'dados_txt1.txt'
np.savetxt(file_path, data, delimiter=',', header='x,y', comments='')

# Exibindo o caminho do arquivo salvo
file_path
plt.scatter(x,y)

# %%
modelo = LinearRegression()
modelo.fit(x,y)
# Out:
# LinearRegression()

# %%
#matematical model

a_coeff = modelo.coef_
l_coeff = modelo.intercept_

#Don't be afraid if this cell gets ERROR, it's part of the plan
y = a + b*x
y = l_coeff + a_coeff * x
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 4
#       1 a_coeff = modelo.coef_
#       2 l_coeff = modelo.intercept_
# ----> 4 y = a + b*x
#       5 y = l_coeff + a_coeff * x
#
# NameError: name 'a' is not defined

# %%
#Showing the linear and angular coeficients
print('Angular Coeficiente : {0}\nLinear Coeficiente  {1}'.format(a_coeff,l_coeff))
# Out:
# Angular Coeficiente : [57.80285165]
# Linear Coeficiente  11.722700243778768

# %%
#Ploting
plt.scatter(x,y)

# Defining the line in x reference
plt.plot(x, l_coeff + a_coeff*x , color='red')

#making the scatter on case x = 2.5
plt.scatter(2.5, l_coeff + a_coeff*2.5, color='green')

#Showing the graph
plt.show()
